# %%
import numpy as np

# %%
np.random.uniform(low=0, high=1, size=(4,5,2,8))
# Out:
# array([[[[0.78073113, 0.74762498, 0.42671466, 0.29119108, 0.75865579,
#           0.32725795, 0.81911098, 0.83889452],
#          [0.85476472, 0.72593781, 0.46013063, 0.32289404, 0.02108438,
#           0.73337933, 0.27382805, 0.94515252]],
#
#         [[0.06317576, 0.00528282, 0.52068945, 0.75077707, 0.3250714 ,
#           0.96287813, 0.56934731, 0.40457707],
#          [0.67557654, 0.10954934, 0.51887842, 0.78800806, 0.89739278,
#           0.25703209, 0.32346285, 0.36288398]],
#
#         [[0.90489473, 0.77209317, 0.78267364, 0.44777398, 0.1182652 ,
#           0.98254664, 0.80098596, 0.2261337 ],
#          [0.43794055, 0.70026701, 0.36807836, 0.01804726, 0.22111512,
#           0.02002331, 0.39579682, 0.07838764]],
#
#         [[0.58210877, 0.31647708, 0.43042037, 0.14631716, 0.42621831,
#           0.2184384 , 0.65140368, 0.35707483],
#          [0.85158406, 0.31784562, 0.04467432, 0.60361774, 0.96667369,
#           0.54354445, 0.34723277, 0.19285769]],
#
# ...
